# %% [markdown]
# ### Se importan las librerias necesarias

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# * **pandas:** Para cargar y manipular los datos en DataFrames.
# * **sklearn.preprocessing:** Contiene clases para realizar diferentes tipos de escalado y normalización.

# %% [markdown]
# ### Cargar los datos:

# %%
data = pd.read_csv("/content/cleaned_dataset.csv")

# %% [markdown]
# ## Viisualizar datos

# %%
data.head()
# Out:
#          term  int_rate  installment sub_grade  emp_length home_ownership  \
# 0   36 months     10.99       885.46        B2        10.0            OWN
# 1   36 months     13.98       333.14        C1         1.0           RENT
# 2   36 months      6.62       368.45        A2        10.0       MORTGAGE
# 3   36 months     13.53       407.40        B5        10.0           RENT
# 4   36 months      8.90       476.30        A5         2.0       MORTGAGE
#
#    annual_inc verification_status  loan_status             purpose  ...  \
# 0     55000.0            Verified            1  debt_consolidation  ...
# 1     26000.0        Not Verified            1  debt_consolidation  ...
# 2    105000.0        Not Verified            1  debt_consolidation  ...
# 3     40000.0     Source Verified            1  debt_consolidation  ...
# 4     63000.0        Not Verified            1  debt_consolidation  ...
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  last_pymnt_amnt  \
# ...

# %% [markdown]
# ### Normalizamos las columnas numericasç

# %%
# Seleccionar las columnas numéricas para normalizar
numeric_cols = ['int_rate', 'installment', 'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths',
                'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'out_prncp',
                'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'last_pymnt_amnt',
                'collections_12_mths_ex_med', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim']

# Crear un objeto StandardScaler
scaler = MinMaxScaler()
# Out:
#          term  int_rate  installment sub_grade  emp_length home_ownership  \
# 0   36 months  0.248754     0.622586        B2        10.0            OWN
# 1   36 months  0.397807     0.223761        C1         1.0           RENT
# 2   36 months  0.030907     0.249258        A2        10.0       MORTGAGE
# 3   36 months  0.375374     0.277383        B5        10.0           RENT
# 4   36 months  0.144566     0.327135        A5         2.0       MORTGAGE
#
#    annual_inc verification_status  loan_status             purpose  ...  \
# 0    0.006658            Verified            1  debt_consolidation  ...
# 1    0.002593        Not Verified            1  debt_consolidation  ...
# 2    0.013666        Not Verified            1  debt_consolidation  ...
# 3    0.004555     Source Verified            1  debt_consolidation  ...
# 4    0.007779        Not Verified            1  debt_consolidation  ...
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  last_pymnt_amnt  \
# ...

# %% [markdown]
# ### Ajustar el escalador a los datos y transformar las columnas numéricas y imprimimos los primeros 5 registros normalizados

# %%
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])

data.head()
# Out:
#          term  int_rate  installment sub_grade  emp_length home_ownership  \
# 0   36 months  0.248754     0.622586        B2        10.0            OWN
# 1   36 months  0.397807     0.223761        C1         1.0           RENT
# 2   36 months  0.030907     0.249258        A2        10.0       MORTGAGE
# 3   36 months  0.375374     0.277383        B5        10.0           RENT
# 4   36 months  0.144566     0.327135        A5         2.0       MORTGAGE
#
#    annual_inc verification_status  loan_status             purpose  ...  \
# 0    0.006658            Verified            1  debt_consolidation  ...
# 1    0.002593        Not Verified            1  debt_consolidation  ...
# 2    0.013666        Not Verified            1  debt_consolidation  ...
# 3    0.004555     Source Verified            1  debt_consolidation  ...
# 4    0.007779        Not Verified            1  debt_consolidation  ...
#
#    total_rec_prncp  total_rec_int  total_rec_late_fee  last_pymnt_amnt  \
# ...

# %%
data.to_csv('normalized_loan_data.csv', index=False)
